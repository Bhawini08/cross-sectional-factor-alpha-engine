# %% [markdown]
# # Cross-Sectional Factor Research & Alpha Validation Engine
# Walkthrough notebook. Run from the repository root after installing requirements.

# %%
import sys; sys.path.append('../src')
from factor_alpha.pipeline import run_research
metrics = run_research('synthetic', '../results', 'SPY')
metrics

# %% [markdown]
# ## Interpretation checklist
# - Is HAC alpha statistically significant?
# - Is annualized alpha economically meaningful?
# - Are VIFs high enough to make individual betas unstable?
# - How many PCs explain most factor variance?
# - Do rolling betas shift materially?
# - Do OLS/Ridge/Lasso retain positive OOS R²?
